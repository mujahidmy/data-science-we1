# %%
print("hello world")
# Out:
# hello world

# %%
x=5
print("The number you entered is :\n",x)
# Out:
# The number you entered is :
#  5

# %%
x=
print("the floating number is :",x)
print(type(x))
# Out:
# the floating number is : 0
# <class 'int'>
