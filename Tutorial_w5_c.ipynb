# %% [markdown]
# <a href="https://colab.research.google.com/github/mujahidmy/data-science-we1/blob/main/Tutorial_w5_c.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Source - http://stackoverflow.com/a
# Posted by tanemaki, modified by community. See post 'Timeline' for change history
# Retrieved 2025-11-12, License - CC BY-SA 4.0

import pandas as pd
import numpy as np
from scipy import stats

df = pd.DataFrame(np.random.randn(100, 3))

df[(np.abs(stats.zscore(df)) < 3).all(axis=1)] # Many standard deviations a data point is from the mean of its dataset.Z-score

print(df)
# Out:
#            0         1         2
# 0   0.201925 -1.212940  0.865624
# 1  -0.865533 -0.006071  0.246219
# 2   0.768759 -0.801479 -1.052909
# 3  -0.179590  0.388508  0.874044
# 4   0.451195  0.162048 -0.967911
# ..       ...       ...       ...
# 95  1.186777 -0.495740 -1.249305
# 96  1.103698  1.156224 -0.610109
# 97  2.024295  0.754138 -1.926660
# 98 -1.851202  0.308143  0.591917
# 99  1.230494  0.103238 -0.067292
#
# [100 rows x 3 columns]

# %%
# Step 1: Create a simple dataframe with obvious outliers
data = {
    'Score': [85, 90, 78, 92, 88, 200, 85, 89, -50, 87]
}
df = pd.DataFrame(data)

print("ORIGINAL DATA: ")
print(df)

# Step 2: Romove outliers using Z-score method
df_clean = df[(np.abs(stats.zscore(df)) < 2).all(axis=1)]

print("\nCLEANED DATA (outliers removed): ")
print(df_clean)

# Step 3: Show what happened
print(f"\nSUMMARY: ")
print(f"Original rows: {len(df)}")
print(f"Rows after cleaning: {len(df_clean)}")
print(f"Outliers removed: {len(df) - len(df_clean)}")
# Out:
# ORIGINAL DATA:
#    Score
# 0     85
# 1     90
# 2     78
# 3     92
# 4     88
# 5    200
# 6     85
# 7     89
# 8    -50
# 9     87
#
# CLEANED DATA (outliers removed):
#    Score
# 0     85
# 1     90
# 2     78
# 3     92
# 4     88
# 6     85
# 7     89
# 9     87
#
# SUMMARY:
# Original rows: 10
# Rows after cleaning: 8
# Outliers removed: 2
